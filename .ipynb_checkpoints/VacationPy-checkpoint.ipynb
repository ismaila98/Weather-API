# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests
import json

# Import API key
from api_keys import geoapify_key

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID           City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0         kodiak  57.7900 -152.4072     -2.27        93         100
# 1        1  pacific grove  36.6177 -121.9166     11.17        85           0
# 2        2         hobart -42.8794  147.3294     18.48        55          75
# 3        3    clyde river  70.4692  -68.5914    -31.69        97         100
# 4        4          yushu  44.8000  126.5333    -12.47        76          93
#
#    Wind Speed Country        Date
# 0        2.57      US  1674097955
# 1        0.89      US  1674097956
# 2        7.72      AU  1674097932
# 3        0.82      CA  1674097958
# 4        3.38      CN  1674097958

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

map_plot = city_data_df.hvplot.points(
    "Lng", 
    "Lat", 
    geo = True, 
    size = "Max Temp",
    scale = 1,
    color = "City",
    tiles = "OSM",
    frame_width = 500,
    frame_height = 500
    )

map_plot
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Max Temp)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
filter_weather_df = city_data_df.loc[(city_data_df["Max Temp"] > 20) & (city_data_df["Max Temp"] < 35) &
                                    (city_data_df["Cloudiness"] == 0)]


filter_weather_df = filter_weather_df.dropna()
filter_weather_df.reset_index(inplace=True)
filter_weather_df.head()
# Out:
#    index  City_ID        City      Lat       Lng  Max Temp  Humidity  \
# 0     24       24     ballina -28.8667  153.5667     30.56        59
# 1     47       47      ixtapa  20.7000 -105.2000     21.57        73
# 2     59       59   busselton -33.6500  115.3333     27.26        37
# 3     61       61  port pirie -33.1833  138.0167     24.85        20
# 4    179      179      bombay  19.0144   72.8479     21.99        68
#
#    Cloudiness  Wind Speed Country        Date
# 0           0        6.43      AU  1674097968
# 1           0        0.00      MX  1674097979
# 2           0        2.87      AU  1674097985
# 3           0        4.87      AU  1674097986
# 4           0        1.54      IN  1674097846

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = filter_weather_df[['City', 'Country', 'Lat', 'Lng', 'Humidity']]
hotel_df['Hotel Name'] = " "
hotel_df
# Out:
# /var/folders/rq/4xxr9vw94lz9d0j67d4dfr800000gn/T/ipykernel_41552/543113887.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hotel_df['Hotel Name'] = " "
#                  City Country      Lat       Lng  Humidity Hotel Name
# 0             ballina      AU -28.8667  153.5667        59
# 1              ixtapa      MX  20.7000 -105.2000        73
# 2           busselton      AU -33.6500  115.3333        37
# 3          port pirie      AU -33.1833  138.0167        20
# 4              bombay      IN  19.0144   72.8479        68
# 5           carnarvon      AU -24.8667  113.6333        52
# 6             mildura      AU -34.2000  142.1500        39
# 7       makakilo city      US  21.3469 -158.0858        61
# 8             salalah      OM  17.0151   54.0924        46
# 9               pisco      PE -13.7000  -76.2167        73
# 10        broken hill      AU -31.9500  141.4333        21
# 11          byron bay      AU -28.6500  153.6167        54
# 12          caravelas      BR -17.7125  -39.2481        91
# 13  sao joao da barra      BR -21.6403  -41.0511        89
# 14           key west      US  24.5557  -81.7826        84
# 15         oranjestad      AW  12.5240  -70.0270        84
# 16             albury      AU -36.0833  146.9167        94

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000
categories = "accommodation.hotel"
params = {
    "categories":categories,
    "apiKey":geoapify_key    
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    Lat = row["Lat"]
    Lng = row["Lng"]
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f'circle:{Lng},{Lat},{radius}'
    params["bias"] = f'proximity:{Lng},{Lat}'
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionaty
    name_address1 = requests.get(base_url, params=params)
    name_address = name_address1.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
         #If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
        print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

#Display sample data
hotel_df
# Out:
# Starting hotel search
# carnarvon - nearest hotel: No hotel found
#                  City Country      Lat       Lng  Humidity  \
# 0             ballina      AU -28.8667  153.5667        59
# 1              ixtapa      MX  20.7000 -105.2000        73
# 2           busselton      AU -33.6500  115.3333        37
# 3          port pirie      AU -33.1833  138.0167        20
# 4              bombay      IN  19.0144   72.8479        68
# 5           carnarvon      AU -24.8667  113.6333        52
# 6             mildura      AU -34.2000  142.1500        39
# 7       makakilo city      US  21.3469 -158.0858        61
# 8             salalah      OM  17.0151   54.0924        46
# 9               pisco      PE -13.7000  -76.2167        73
# 10        broken hill      AU -31.9500  141.4333        21
# 11          byron bay      AU -28.6500  153.6167        54
# 12          caravelas      BR -17.7125  -39.2481        91
# 13  sao joao da barra      BR -21.6403  -41.0511        89
# 14           key west      US  24.5557  -81.7826        84
# 15         oranjestad      AW  12.5240  -70.0270        84
# 16             albury      AU -36.0833  146.9167        94
#
#                                Hotel Name
# 0                    Ballina Beach Resort
# 1                            Ma. Cristina
# 2                 Broadwater Beach Resort
# 3                             Ellen Hotel
# 4                        Hotel City Point
# 5                          No hotel found
# 6                       Chaffey Motor Inn
# 7   Embassy Suites by Hilton Oahu Kapolei
# 8              Muscat International Hotel
# 9                              La Portada
# 10                            Ibis Styles
# 11                      Lord Byron Resort
# 12                 Pousada dos Navegantes
# 13                   Pousada Mediterrâneo
# 14              Harborside Hotel & Marina
# 15                       Hotel California
# 16                           Mantra Hotel

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display
map_plot1 = hotel_df.hvplot.points(
    "Lng", 
    "Lat", 
    geo = True, 
    size = "Max Temp",
    scale = 1,
    color = "City",
    tiles = "OSM",
    frame_width = 500,
    frame_height = 500,
    hover_cols=["Lng", "Lat", "Humidity", "City", "Country", "Hotel Name"]
    )
map_plot1
# Out:
# WARNING:param.GeoPointPlot02611: Specified size dim transform (np.sqrt(dim('Max Temp'))*1) could not be applied, as not all dimensions could be resolved.
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Country,Hotel Name)
